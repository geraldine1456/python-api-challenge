# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='56180b42-68a4-4b6c-a447-92e1f9318bd3'>
#   <div id="bf94b31d-8261-43b1-85b3-30fc1b9a44e5" data-root-id="56180b42-68a4-4b6c-a447-92e1f9318bd3" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID                 City      Lat       Lng  Max Temp  Humidity  \
# 0        0                 nata   8.3333  -80.5167     27.65        85
# 1        1  saint-jean-de-monts  46.7833   -2.0667     14.58        85
# 2        2               kodiak  57.7900 -152.4072      7.73        93
# 3        3    wailua homesteads  22.0669 -159.3780     27.44        75
# 4        4            tocopilla -22.0920  -70.1979     18.49        76
#
#    Cloudiness  Wind Speed Country        Date
# 0          84        2.75      PA  1749344705
# 1           0        8.63      FR  1749344706
# 2         100        4.12      US  1749344707
# 3          20        5.14      US  1749344709
# 4          18        5.76      CL  1749344483

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
cities_map = city_data_df.hvplot.points( "Lng", "Lat", tiles="OSM", geo=True, height=400, width=1000, size="Humidity", hover_cols="City",color= "City" )

# Display the map
cities_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] < 28) &
    (city_data_df["Max Temp"] > 20) &
    (city_data_df["Wind Speed"] < 4.5) &
    (city_data_df["Cloudiness"] == 0)
]

# Drop any rows with null values
ideal_cities_cl_df = ideal_cities_df.dropna()

#Display sample data
ideal_cities_cl_df
# Out:
#      City_ID              City      Lat       Lng  Max Temp  Humidity  \
# 20        20             sirte  31.2089   16.5887     21.97        63
# 38        38       kapuskasing  49.4169  -82.4331     20.05        45
# 55        55           tortoli  39.9256    9.6572     23.97        63
# 77        77            tukrah  32.5341   20.5791     22.47        59
# 102      102              roma  43.2128  -75.4557     20.37        71
# 122      122             hotan  37.0997   79.9269     27.95        10
# 137      137          beatrice  40.2681  -96.7470     26.05        47
# 163      163         boa vista   2.8197  -60.6733     26.99        78
# 188      188              akko  32.9236   35.0728     21.15        90
# 225      225           douglas  41.3000  -96.1670     25.49        55
# 234      234  kill devil hills  36.0307  -75.6760     24.01        94
# 266      266           toliara -23.3500   43.6667     20.96        66
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_cities_cl_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                  City Country      Lat       Lng  Humidity Hotel Name
# 20              sirte      LY  31.2089   16.5887        63
# 38        kapuskasing      CA  49.4169  -82.4331        45
# 55            tortoli      IT  39.9256    9.6572        63
# 77             tukrah      LY  32.5341   20.5791        59
# 102              roma      US  43.2128  -75.4557        71
# 122             hotan      CN  37.0997   79.9269        10
# 137          beatrice      US  40.2681  -96.7470        47
# 163         boa vista      BR   2.8197  -60.6733        78
# 188              akko      IL  32.9236   35.0728        90
# 225           douglas      US  41.3000  -96.1670        55
# 234  kill devil hills      US  36.0307  -75.6760        94
# 266           toliara      MG -23.3500   43.6667        66
# 287              tura      IN  25.5198   90.2201        71
# 309           bekobod      UZ  40.2208   69.2697        63
# 310           beipiao      CN  41.7919  120.7792        23
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius =  10000 
params =  {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    Lat, Lng = row["Lat"], row["Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{Lng},{Lat},{radius}"
    params["bias"] = f"proximity:{Lng},{Lat}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# sirte - nearest hotel: فندق المدينة-سرت
# kapuskasing - nearest hotel: Travelodge
# tortoli - nearest hotel: La Corte
# tukrah - nearest hotel: No hotel found
# roma - nearest hotel: Hampton
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# beatrice - nearest hotel: Victorian Inn Beatrice
# boa vista - nearest hotel: Aipana Plaza Hotel
# akko - nearest hotel: מלון עכוטל
# douglas - nearest hotel: Holiday Inn Express
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# toliara - nearest hotel: Ambary
# tura - nearest hotel: Hotel Polo Orchid
# bekobod - nearest hotel: BEK
# beipiao - nearest hotel: No hotel found
# chaoyang - nearest hotel: 燕都国际酒店
# at taraf - nearest hotel: No hotel found
# liuhe - nearest hotel: 柳河大米姐酒店
# urangan - nearest hotel: Ramada
# sussex - nearest hotel: Quality Inn
# nueva gerona - nearest hotel: Hotel Bamboo
# inhambane - nearest hotel: Hotel de Inhambane
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
cities_map = hotel_df.hvplot.points(
    "Lng", "Lat", tiles="OSM", geo=True, height=400, width=1000, 
    size="Humidity", 
    hover_cols=["City","Hotel Name", "Country"],
    color= "City"      
    )

# Display the map
cities_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
