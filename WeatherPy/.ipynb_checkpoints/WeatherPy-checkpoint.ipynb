# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 605

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "Metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}units={units}&q={city}&appid={weather_api_key}"  

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
      
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds =city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
     
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nata
# Processing Record 2 of Set 1 | saint-jean-de-monts
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | wailua homesteads
# Processing Record 5 of Set 1 | tocopilla
# Processing Record 6 of Set 1 | nemuro
# Processing Record 7 of Set 1 | kone
# Processing Record 8 of Set 1 | chonchi
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | port mathurin
# Processing Record 11 of Set 1 | port-aux-francais
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | adamstown
# Processing Record 14 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 15 of Set 1 | papatowai
# Processing Record 16 of Set 1 | lihue
# Processing Record 17 of Set 1 | pervomays'kyy
# Processing Record 18 of Set 1 | kangding
# Processing Record 19 of Set 1 | vorgashor
# Processing Record 20 of Set 1 | west island
# Processing Record 21 of Set 1 | klyuchi
# Processing Record 22 of Set 1 | sirte
# Processing Record 23 of Set 1 | revda
# Processing Record 24 of Set 1 | natal
# Processing Record 25 of Set 1 | anadyr
# Processing Record 26 of Set 1 | blackmans bay
# Processing Record 27 of Set 1 | hamilton
# Processing Record 28 of Set 1 | tiksi
# Processing Record 29 of Set 1 | paita
# Processing Record 30 of Set 1 | port lincoln
# Processing Record 31 of Set 1 | kapa'a
# Processing Record 32 of Set 1 | kununurra
# Processing Record 33 of Set 1 | kerikeri
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | ulanhot
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 38 of Set 1 | ust'-ilimsk
# Processing Record 39 of Set 1 | grytviken
# Processing Record 40 of Set 1 | enid
# Processing Record 41 of Set 1 | kapuskasing
# Processing Record 42 of Set 1 | edinburgh of the seven seas
# Processing Record 43 of Set 1 | puerto aysen
# Processing Record 44 of Set 1 | hermanus
# Processing Record 45 of Set 1 | san patricio
# Processing Record 46 of Set 1 | taroa
# Processing Record 47 of Set 1 | tymovskoye
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | saipan
# Processing Record 50 of Set 1 | preobrazheniye
# Processing Record 0 of Set 2 | cabedelo
# Processing Record 1 of Set 2 | qasr-e qand
# City not found. Skipping...
# Processing Record 2 of Set 2 | gillette
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | mahina
# Processing Record 5 of Set 2 | uricani
# Processing Record 6 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | san antonio oeste
# Processing Record 9 of Set 2 | tortoli
# Processing Record 47 of Set 4 | akko
# Processing Record 48 of Set 4 | horta
# Processing Record 49 of Set 4 | conception bay south
# Processing Record 0 of Set 5 | aykhal
# Processing Record 1 of Set 5 | praya
# Processing Record 2 of Set 5 | salinopolis
# Processing Record 3 of Set 5 | kavieng
# Processing Record 4 of Set 5 | fisterra
# Processing Record 5 of Set 5 | nouadhibou
# Processing Record 6 of Set 5 | kiunga
# Processing Record 7 of Set 5 | kachug
# Processing Record 8 of Set 5 | la ronge
# Processing Record 9 of Set 5 | seguela
# Processing Record 10 of Set 5 | cestos city
# Processing Record 11 of Set 5 | priob'ye
# Processing Record 12 of Set 5 | tolanaro
# Processing Record 13 of Set 5 | walvis bay
# Processing Record 14 of Set 5 | labytnangi
# Processing Record 15 of Set 5 | jalai nur
# Processing Record 16 of Set 5 | hastings
# Processing Record 17 of Set 5 | port saint john's
# Processing Record 18 of Set 5 | blaby
# Processing Record 19 of Set 5 | vila franca do campo
# Processing Record 20 of Set 5 | pangoa
# Processing Record 21 of Set 5 | laramie
# Processing Record 22 of Set 5 | bikenibeu village
# Processing Record 23 of Set 5 | robertsport
# Processing Record 24 of Set 5 | san onofre
# Processing Record 25 of Set 5 | saint-francois
# Processing Record 26 of Set 5 | westport
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | margate
# Processing Record 29 of Set 5 | san antonio de pale
# Processing Record 30 of Set 5 | tikhvin
# Processing Record 31 of Set 5 | portland
# Processing Record 32 of Set 5 | hami
# Processing Record 33 of Set 5 | san luis
# Processing Record 34 of Set 5 | douglas
# Processing Record 35 of Set 5 | adrar
# Processing Record 36 of Set 5 | waingapu
# Processing Record 37 of Set 5 | tucuma
# Processing Record 38 of Set 5 | hithadhoo
# Processing Record 39 of Set 5 | garhdiwala
# Processing Record 40 of Set 5 | kyshtovka
# Processing Record 41 of Set 5 | mangalia
# Processing Record 42 of Set 5 | fale old settlement
# Processing Record 43 of Set 5 | kill devil hills
# Processing Record 44 of Set 5 | buala
# Processing Record 45 of Set 5 | suntar
# Processing Record 46 of Set 5 | baoqing
# Processing Record 47 of Set 5 | muroto-misakicho
# Processing Record 48 of Set 5 | saint-philippe
# Processing Record 49 of Set 5 | watampone
# Processing Record 0 of Set 6 | arraial do cabo
# Processing Record 1 of Set 6 | fortuna
# Processing Record 2 of Set 6 | san luis de la loma
# Processing Record 3 of Set 6 | isangel
# Processing Record 4 of Set 6 | opuwo
# Processing Record 5 of Set 6 | sake
# Processing Record 6 of Set 6 | mahibadhoo
# Processing Record 7 of Set 6 | grand falls-windsor
# Processing Record 8 of Set 6 | weno
# Processing Record 9 of Set 6 | marsh harbour
# Processing Record 10 of Set 6 | mil'kovo
# Processing Record 11 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 12 of Set 6 | port isabel
# Processing Record 13 of Set 6 | fall river
# Processing Record 14 of Set 6 | woolgoolga
# Processing Record 15 of Set 6 | ad dilam
# Processing Record 16 of Set 6 | tsiombe
# Processing Record 17 of Set 6 | lembar
# City not found. Skipping...
# Processing Record 18 of Set 6 | barpali
# Processing Record 19 of Set 6 | itoman
# Processing Record 20 of Set 6 | manokwari
# Processing Record 21 of Set 6 | sao joao da barra
# Processing Record 22 of Set 6 | kavaratti
# Processing Record 23 of Set 6 | kailua-kona
# Processing Record 24 of Set 6 | karratha
# Processing Record 25 of Set 6 | moratuwa
# Processing Record 26 of Set 6 | la crosse
# Processing Record 27 of Set 6 | toliara
# Processing Record 28 of Set 6 | palopo
# Processing Record 29 of Set 6 | kingston
# Processing Record 30 of Set 6 | itapirapua
# Processing Record 31 of Set 6 | novyy turtkul'
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | panama city beach
# Processing Record 34 of Set 6 | ormara
# Processing Record 35 of Set 6 | sola
# Processing Record 36 of Set 6 | rudnichnyy
# Processing Record 37 of Set 6 | wotje
# Processing Record 38 of Set 6 | metlili chaamba
# Processing Record 39 of Set 6 | la passe
# Processing Record 40 of Set 6 | stawell
# Processing Record 41 of Set 6 | nanzhang chengguanzhen
# Processing Record 42 of Set 6 | valbo
# Processing Record 43 of Set 6 | alice springs
# Processing Record 44 of Set 6 | bargaal
# Processing Record 45 of Set 6 | college
# Processing Record 46 of Set 6 | wagga wagga
# Processing Record 47 of Set 6 | broken hill
# Processing Record 48 of Set 6 | tura
# Processing Record 49 of Set 6 | laojunmiao
# Processing Record 0 of Set 7 | bath
# Processing Record 1 of Set 7 | tazovsky
# Processing Record 2 of Set 7 | nanlong
# Processing Record 3 of Set 7 | koundara
# Processing Record 4 of Set 7 | venancio aires
# Processing Record 5 of Set 7 | silveira
# Processing Record 6 of Set 7 | gaiman
# Processing Record 7 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 7 | bermeo
# Processing Record 9 of Set 7 | sona
# Processing Record 10 of Set 7 | kodinsk
# Processing Record 11 of Set 7 | nishinoomote
# Processing Record 12 of Set 7 | leppavirta
# Processing Record 13 of Set 7 | novovarshavka
# Processing Record 14 of Set 7 | palmer
# Processing Record 15 of Set 7 | buka
# Processing Record 16 of Set 7 | ubajara
# Processing Record 17 of Set 7 | songling
# Processing Record 18 of Set 7 | khandyga
# Processing Record 19 of Set 7 | dapa
# Processing Record 20 of Set 7 | camden
# Processing Record 21 of Set 7 | bekobod
# Processing Record 22 of Set 7 | kawthoung
# City not found. Skipping...
# Processing Record 23 of Set 7 | beipiao
# Processing Record 24 of Set 7 | rakops
# Processing Record 25 of Set 7 | nanao
# Processing Record 26 of Set 7 | hadibu
# Processing Record 27 of Set 7 | happy valley-goose bay
# Processing Record 28 of Set 7 | madang
# Processing Record 29 of Set 7 | summerside
# Processing Record 30 of Set 7 | selfoss
# Processing Record 31 of Set 7 | island harbour
# Processing Record 32 of Set 7 | georgetown
# Processing Record 33 of Set 7 | mingguang
# Processing Record 34 of Set 7 | bubaque
# Processing Record 35 of Set 7 | miass
# Processing Record 5 of Set 9 | pokachi
# Processing Record 6 of Set 9 | kutum
# Processing Record 7 of Set 9 | lorengau
# Processing Record 8 of Set 9 | stettler
# Processing Record 9 of Set 9 | kuanda
# Processing Record 10 of Set 9 | inhambane
# Processing Record 11 of Set 9 | colonia
# Processing Record 12 of Set 9 | ghadamis
# Processing Record 13 of Set 9 | camabatela
# Processing Record 14 of Set 9 | shenjiamen
# Processing Record 15 of Set 9 | mana
# Processing Record 16 of Set 9 | ak-suu
# Processing Record 17 of Set 9 | mandalgovi
# Processing Record 18 of Set 9 | muang phon-hong
# Processing Record 19 of Set 9 | boguchany
# Processing Record 20 of Set 9 | linxia chengguanzhen
# Processing Record 21 of Set 9 | araripina
# Processing Record 22 of Set 9 | puqi
# Processing Record 23 of Set 9 | yulinshi
# Processing Record 24 of Set 9 | blackwell
# Processing Record 25 of Set 9 | as suwayrah
# Processing Record 26 of Set 9 | abergavenny
# Processing Record 27 of Set 9 | thinadhoo
# Processing Record 28 of Set 9 | bonthe
# Processing Record 29 of Set 9 | valparaiso
# Processing Record 30 of Set 9 | santona
# Processing Record 31 of Set 9 | tromso
# Processing Record 32 of Set 9 | chernomorskoye
# Processing Record 33 of Set 9 | luderitz
# Processing Record 34 of Set 9 | sabang
# Processing Record 35 of Set 9 | barry
# Processing Record 36 of Set 9 | katsuren-haebaru
# Processing Record 37 of Set 9 | mitu
# Processing Record 38 of Set 9 | newman
# Processing Record 39 of Set 9 | port douglas
# Processing Record 40 of Set 9 | sheregesh
# Processing Record 41 of Set 9 | al wafrah
# Processing Record 42 of Set 9 | kolonia
# Processing Record 43 of Set 9 | sorong
# Processing Record 44 of Set 9 | franklin
# Processing Record 45 of Set 9 | kismayo
# Processing Record 46 of Set 9 | keningau
# Processing Record 47 of Set 9 | macau
# Processing Record 48 of Set 9 | sinop
# Processing Record 49 of Set 9 | kingman
# Processing Record 0 of Set 10 | berdigestyakh
# Processing Record 1 of Set 10 | codrington
# Processing Record 2 of Set 10 | saint george's
# Processing Record 3 of Set 10 | mengyin
# Processing Record 4 of Set 10 | rundu
# Processing Record 5 of Set 10 | kalix
# Processing Record 6 of Set 10 | bridgetown
# Processing Record 7 of Set 10 | dunedin
# Processing Record 8 of Set 10 | urzhar
# Processing Record 9 of Set 10 | concordia
# Processing Record 10 of Set 10 | brisas de zicatela
# Processing Record 11 of Set 10 | fauske
# Processing Record 12 of Set 10 | cascais
# Processing Record 13 of Set 10 | west point
# Processing Record 14 of Set 10 | cam pha mines
# Processing Record 15 of Set 10 | rongelap
# Processing Record 16 of Set 10 | isabela
# Processing Record 17 of Set 10 | fort bragg
# Processing Record 18 of Set 10 | ayr
# Processing Record 19 of Set 10 | houlton
# Processing Record 20 of Set 10 | inda silase
# Processing Record 21 of Set 10 | necochea
# Processing Record 22 of Set 10 | goianapolis
# Processing Record 23 of Set 10 | mugia
# Processing Record 24 of Set 10 | harstad
# Processing Record 25 of Set 10 | alofi
# Processing Record 26 of Set 10 | maxixe
# Processing Record 27 of Set 10 | genteng
# Processing Record 28 of Set 10 | altoona
# Processing Record 29 of Set 10 | bom jesus do itabapoana
# Processing Record 30 of Set 10 | bereznik
# Processing Record 31 of Set 10 | yangiobod
# Processing Record 32 of Set 10 | sao desiderio
# Processing Record 33 of Set 10 | baiyin
# Processing Record 34 of Set 10 | bloemfontein
# Processing Record 35 of Set 10 | sao jose da coroa grande
# Processing Record 36 of Set 10 | garoowe
# Processing Record 37 of Set 10 | twin falls
# Processing Record 38 of Set 10 | alo
# Processing Record 39 of Set 10 | faya-largeau
# Processing Record 40 of Set 10 | pontes e lacerda
# Processing Record 41 of Set 10 | sequim
# Processing Record 42 of Set 10 | egilsstadir
# Processing Record 43 of Set 10 | santa cruz
# Processing Record 44 of Set 10 | nagqu
# Processing Record 45 of Set 10 | illizi
# Processing Record 46 of Set 10 | alva
# Processing Record 47 of Set 10 | santa cecilia
# Processing Record 48 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 49 of Set 10 | amancio
# Processing Record 0 of Set 11 | sishilichengzi
# City not found. Skipping...
# Processing Record 1 of Set 11 | taoudenni
# Processing Record 2 of Set 11 | anenii noi
# Processing Record 3 of Set 11 | huatabampo
# Processing Record 4 of Set 11 | san jose de jachal
# Processing Record 5 of Set 11 | lidkoping
# Processing Record 6 of Set 11 | pacific grove
# Processing Record 7 of Set 11 | usogorsk
# Processing Record 8 of Set 11 | tame
# Processing Record 9 of Set 11 | dhalie
# Processing Record 10 of Set 11 | san jose del cabo
# Processing Record 11 of Set 11 | smirnykh
# Processing Record 12 of Set 11 | asahikawa
# Processing Record 13 of Set 11 | shingu
# Processing Record 14 of Set 11 | chelakara
# Processing Record 15 of Set 11 | scheveningen
# Processing Record 16 of Set 11 | beli
# Processing Record 17 of Set 11 | palikir - national government center
# Processing Record 18 of Set 11 | okahandja
# Processing Record 19 of Set 11 | cedar park
# Processing Record 20 of Set 11 | yatou
# Processing Record 21 of Set 11 | praia da vitoria
# Processing Record 22 of Set 11 | al jawf
# Processing Record 23 of Set 11 | palapag
# Processing Record 24 of Set 11 | siliguri
# Processing Record 25 of Set 11 | fallon
# Processing Record 26 of Set 11 | general jose de san martin
# Processing Record 27 of Set 11 | belmonte
# Processing Record 28 of Set 11 | slavutych
# Processing Record 29 of Set 11 | as sulayyil
# Processing Record 30 of Set 11 | betio village
# Processing Record 31 of Set 11 | laminusa
# Processing Record 32 of Set 11 | al burayqah
# Processing Record 33 of Set 11 | lucas
# Processing Record 34 of Set 11 | den burg
# Processing Record 35 of Set 11 | farasan
# Processing Record 36 of Set 11 | beau vallon
# Processing Record 37 of Set 11 | queenstown
# Processing Record 38 of Set 11 | saint-pierre
# Processing Record 39 of Set 11 | price
# Processing Record 40 of Set 11 | papao
# Processing Record 41 of Set 11 | itupiranga
# Processing Record 42 of Set 11 | cooma
# Processing Record 43 of Set 11 | flying fish cove
# Processing Record 44 of Set 11 | vernon
# Processing Record 45 of Set 11 | penzance
# Processing Record 46 of Set 11 | naze
# Processing Record 47 of Set 11 | bantogon
# Processing Record 48 of Set 11 | touros
# Processing Record 49 of Set 11 | amga
# Processing Record 0 of Set 12 | tibati
# Processing Record 1 of Set 12 | ternate
# Processing Record 2 of Set 12 | east ballina
# Processing Record 3 of Set 12 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 4 of Set 12 | jayapura
# Processing Record 5 of Set 12 | sandpoint
# Processing Record 6 of Set 12 | maracaju
# Processing Record 7 of Set 12 | yurimaguas
# Processing Record 8 of Set 12 | vokhtoga
# Processing Record 9 of Set 12 | tazacorte
# Processing Record 10 of Set 12 | marang
# Processing Record 11 of Set 12 | chemin grenier
# Processing Record 12 of Set 12 | jose mariano jimenez
# City not found. Skipping...
# Processing Record 13 of Set 12 | paros
# Processing Record 14 of Set 12 | juneau
# Processing Record 15 of Set 12 | antsiranana
# Processing Record 16 of Set 12 | sawston
# Processing Record 17 of Set 12 | malabo
# Processing Record 18 of Set 12 | talodi
# Processing Record 19 of Set 12 | yashkul'
# Processing Record 20 of Set 12 | plasencia
# Processing Record 21 of Set 12 | pangody
# Processing Record 22 of Set 12 | tobruk
# Processing Record 23 of Set 12 | inekar
# City not found. Skipping...
# Processing Record 24 of Set 12 | nea moudhania
# City not found. Skipping...
# Processing Record 25 of Set 12 | quinta del cedro
# City not found. Skipping...
# Processing Record 26 of Set 12 | zouerate
# Processing Record 27 of Set 12 | sabha
# Processing Record 28 of Set 12 | calvinia
# Processing Record 29 of Set 12 | bidur
# Processing Record 30 of Set 12 | isla vista
# Processing Record 31 of Set 12 | yangambi
# Processing Record 32 of Set 12 | val-d'or
# Processing Record 33 of Set 12 | remire-montjoly
# Processing Record 34 of Set 12 | tamanrasset
# Processing Record 35 of Set 12 | abbeville
# Processing Record 36 of Set 12 | shahrak
# Processing Record 37 of Set 12 | villa emilio carranza
# Processing Record 38 of Set 12 | antonio enes
# Processing Record 39 of Set 12 | nueva imperial
# Processing Record 40 of Set 12 | majenang
# Processing Record 41 of Set 12 | murakami
# Processing Record 42 of Set 12 | bafia
# Processing Record 43 of Set 12 | kamuli
# Processing Record 44 of Set 12 | oswestry
# Processing Record 45 of Set 12 | qamdo
# Processing Record 46 of Set 12 | banfora
# Processing Record 47 of Set 12 | al khums
# Processing Record 48 of Set 12 | arteche
# Processing Record 49 of Set 12 | kruisfontein
# Processing Record 0 of Set 13 | kalmunai
# Processing Record 1 of Set 13 | yanchep
# Processing Record 2 of Set 13 | pemangkat
# Processing Record 3 of Set 13 | tadine
# Processing Record 4 of Set 13 | loen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          584
# Lat           584
# Lng           584
# Max Temp      584
# Humidity      584
# Cloudiness    584
# Wind Speed    584
# Country       584
# Date          584
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 nata   8.3333  -80.5167     27.65        85          84
# 1  saint-jean-de-monts  46.7833   -2.0667     14.58        85           0
# 2               kodiak  57.7900 -152.4072      7.73        93         100
# 3    wailua homesteads  22.0669 -159.3780     27.44        75          20
# 4            tocopilla -22.0920  -70.1979     18.49        76          18
#
#    Wind Speed Country        Date
# 0        2.75      PA  1749344705
# 1        8.63      FR  1749344706
# 2        4.12      US  1749344707
# 3        5.14      US  1749344709
# 4        5.76      CL  1749344483

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       nata   8.3333  -80.5167     27.65        85
# 1        saint-jean-de-monts  46.7833   -2.0667     14.58        85
# 2                     kodiak  57.7900 -152.4072      7.73        93
# 3          wailua homesteads  22.0669 -159.3780     27.44        75
# 4                  tocopilla -22.0920  -70.1979     18.49        76
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                84        2.75      PA  1749344705
# 1                 0        8.63      FR  1749344706
# 2               100        4.12      US  1749344707
# 3                20        5.14      US  1749344709
# 4                18        5.76      CL  1749344483

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor='black',  marker="o")

# Incorporate the other graph properties 
plt.title("City Max Latitude vs Temperature (2025-06-05)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor='black', marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs  Humidity (2025-06-05)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor='black', marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs  Cloudiness (2025-06-05)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor='black', marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs  Wind Speed (2025-06-05)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title):
    
    # Creates a scatter plot with linear regression line and shows the R-squared value.
    slope, intercept, r_value, p_value, std_err = stats.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    r_squared = f"R² = {r_value**2:.3f}"

    plt.scatter(x_values,y_values, edgecolor='black', marker="o")
    plt.plot(x_values,regress_values,"r-")

    # Show line equation and R-squared on the plot
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    
    plt.annotate(line_eq, (x_values.min(), y_values.max()*0.65), fontsize=12, color="red")
    plt.annotate(r_squared, (x_values.min(), y_values.max()*.55), fontsize=12, color="red")
    
    plt.title(title)
    
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                       nata   8.3333  -80.5167     27.65        85
# 1        saint-jean-de-monts  46.7833   -2.0667     14.58        85
# 2                     kodiak  57.7900 -152.4072      7.73        93
# 3          wailua homesteads  22.0669 -159.3780     27.44        75
# 5                     nemuro  43.3236  145.5750     12.71        91
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                84        2.75      PA  1749344705
# 1                 0        8.63      FR  1749344706
# 2               100        4.12      US  1749344707
# 3                20        5.14      US  1749344709
# 5                50        1.53      JP  1749344711

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4            tocopilla -22.0920  -70.1979     18.49        76          18
# 6                 kone -21.0595  164.8658     25.67        43          67
# 7              chonchi -42.6128  -73.8092      8.95        92          92
# 8             waitangi -43.9535 -176.5597     11.37        87          76
# 9        port mathurin -19.6833   63.4167     24.31        57           0
#
#          Wind Speed Country        Date
# City_ID
# 4              5.76      CL  1749344483
# 6              0.32      NC  1749344712
# 7              1.01      CL  1749344713
# 8             15.09      NZ  1749344714
# 9              9.89      MU  1749344716

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Max Temp"],
                       "Latitude",
                       "Max Temperature (C)",
                       "Northern Hemisphere: Latitude vs. Max Temperature")

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Max Temp"],
                       "Latitude",
                       "Max Temperature (C)",
                       "Southern Hemisphere: Latitude vs. Max Temperature")

# %% [markdown]
# **Discussion of the Linear Relationship:**
# * The scatter plots reveal a **negative correlation** between latitude and temperature in the **Northern Hemisphere**, where temperature **decreases as the latitude increases**.
# * In contrast, the **Southern Hemisphere** exhibits a **positive correlation**, where temperature **rises with latitude**
# * The strength of this correlation is reinforced by the **relatively high R² value,** suggesting a **consistent and predictable relationship**.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Humidity"],
                       "Latitude",
                       "Humidity (%)",
                       "Northern Hemisphere: Latitude vs. Humidity")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Humidity"],
                       "Latitude",
                       "Humidity (%)",
                       "Southern Hemisphere: Latitude vs. Humidity")

# %% [markdown]
# **Discussion of the Linear Relationship:**
# * Both scatter plots show **no clear correlation** between **latitude** and **humidity**.
# * The **R² values** are very low in both hemispheres, confirming that **latitude is not a significant factor in determining humidity levels**.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Cloudiness"],
                       "Latitude",
                       "Cloudiness (%)",
                       "Northern Hemisphere: Latitude vs. Cloudiness")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Cloudiness"],
                       "Latitude",
                       "Cloudiness (%)",
                       "Southern Hemisphere: Latitude vs. Cloudiness")

# %% [markdown]
# **Discussion of the Linear Relationship:**
# * The scatter plots in both **hemispheres** show **no clear relationship** between latitude and cloudiness.
# * The **R² values** are very low, confirming that **latitude is not a reliable predictor** of cloud cover.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Wind Speed"],
                       "Latitude",
                       "Wind Speed (m/s)",
                       "Northern Hemisphere: Latitude vs. Wind Speed")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Wind Speed"],
                       "Latitude",
                       "Wind Speed (m/s)",
                       "Southern Hemisphere: Latitude vs. Wind Speed")

# %% [markdown]
# **Discussion of the Linear Relationship:**
# * The scatter plots for both **hemispheres** show **no clear correlation** between latitude and wind speed.
# * Both exhibit very low **R² values**, indicating that **latitude is not a significant factor in determining wind speed**.
