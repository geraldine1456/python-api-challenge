# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# https://api.openweathermap.org/data/2.5/weather?q={city name}&appid={API key}

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "Metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}units={units}&q={city}&appid={weather_api_key}"  

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
      
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds =city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]
     
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tralee
# Processing Record 2 of Set 1 | bamboo flat
# Processing Record 3 of Set 1 | olonkinbyen
# Processing Record 4 of Set 1 | puerto natales
# Processing Record 5 of Set 1 | carnarvon
# Processing Record 6 of Set 1 | nova vicosa
# Processing Record 7 of Set 1 | grytviken
# Processing Record 8 of Set 1 | invercargill
# Processing Record 9 of Set 1 | nova sintra
# Processing Record 10 of Set 1 | ta`u
# Processing Record 11 of Set 1 | atafu village
# Processing Record 12 of Set 1 | waitangi
# Processing Record 13 of Set 1 | yellowknife
# Processing Record 14 of Set 1 | tchintabaraden
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | kamaishi
# Processing Record 19 of Set 1 | kenai
# Processing Record 20 of Set 1 | tabou
# Processing Record 21 of Set 1 | edinburgh of the seven seas
# Processing Record 22 of Set 1 | prado
# Processing Record 23 of Set 1 | polyarnyy
# Processing Record 24 of Set 1 | papatowai
# Processing Record 25 of Set 1 | port-aux-francais
# Processing Record 26 of Set 1 | blackmans bay
# Processing Record 27 of Set 1 | saint-joseph
# Processing Record 28 of Set 1 | ust-nera
# Processing Record 29 of Set 1 | iqaluit
# Processing Record 30 of Set 1 | mukalla
# Processing Record 31 of Set 1 | piton saint-leu
# Processing Record 32 of Set 1 | geroskipou
# City not found. Skipping...
# Processing Record 33 of Set 1 | andorra
# Processing Record 34 of Set 1 | west island
# Processing Record 35 of Set 1 | afaahiti
# Processing Record 36 of Set 1 | kuala terengganu
# Processing Record 37 of Set 1 | adamstown
# Processing Record 38 of Set 1 | sai buri
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | isafjordur
# Processing Record 41 of Set 1 | susuman
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | newnham
# Processing Record 44 of Set 1 | sancraieni
# Processing Record 45 of Set 1 | kuanda
# Processing Record 46 of Set 1 | tolanaro
# Processing Record 47 of Set 1 | menongue
# Processing Record 48 of Set 1 | saipan
# Processing Record 49 of Set 1 | saint-pierre
# Processing Record 50 of Set 1 | chos malal
# Processing Record 0 of Set 2 | chonchi
# Processing Record 1 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | stanley
# Processing Record 4 of Set 2 | vadso
# Processing Record 5 of Set 2 | yuzhno-kurilsk
# Processing Record 6 of Set 2 | flin flon
# Processing Record 7 of Set 2 | chernyshevsk
# Processing Record 8 of Set 2 | bilibino
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 48 of Set 4 | guarapari
# Processing Record 49 of Set 4 | ofunato
# Processing Record 0 of Set 5 | usogorsk
# Processing Record 1 of Set 5 | oranjemund
# Processing Record 2 of Set 5 | corzuela
# Processing Record 3 of Set 5 | geraldton
# Processing Record 4 of Set 5 | jiexiu
# Processing Record 5 of Set 5 | toliara
# Processing Record 6 of Set 5 | sisimiut
# Processing Record 7 of Set 5 | ulsteinvik
# Processing Record 8 of Set 5 | meadow lake
# Processing Record 9 of Set 5 | nuuk
# Processing Record 10 of Set 5 | souillac
# Processing Record 11 of Set 5 | la passe
# Processing Record 12 of Set 5 | pirane
# Processing Record 13 of Set 5 | lethem
# Processing Record 14 of Set 5 | yelizovo
# Processing Record 15 of Set 5 | mount gambier
# Processing Record 16 of Set 5 | urengoy
# Processing Record 17 of Set 5 | kingisepp
# Processing Record 18 of Set 5 | luanda
# Processing Record 19 of Set 5 | aswan
# Processing Record 20 of Set 5 | mpika
# Processing Record 21 of Set 5 | big spring
# Processing Record 22 of Set 5 | gadzhiyevo
# Processing Record 23 of Set 5 | buritis
# Processing Record 24 of Set 5 | mogocha
# Processing Record 25 of Set 5 | wynyard
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | ridder
# Processing Record 28 of Set 5 | revda
# Processing Record 29 of Set 5 | fort bragg
# Processing Record 30 of Set 5 | kyaikkami
# Processing Record 31 of Set 5 | fisterra
# Processing Record 32 of Set 5 | vorgashor
# Processing Record 33 of Set 5 | edmundston
# Processing Record 34 of Set 5 | itaituba
# Processing Record 35 of Set 5 | dampit
# Processing Record 36 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 37 of Set 5 | ribeira grande
# Processing Record 38 of Set 5 | wenchang
# Processing Record 39 of Set 5 | barclayville
# Processing Record 40 of Set 5 | santa elena de uairen
# Processing Record 41 of Set 5 | phek
# Processing Record 42 of Set 5 | ust-tsilma
# Processing Record 43 of Set 5 | manga
# Processing Record 44 of Set 5 | mahina
# Processing Record 45 of Set 5 | follonica
# Processing Record 46 of Set 5 | opuwo
# Processing Record 47 of Set 5 | paranhos
# Processing Record 48 of Set 5 | hermanus
# Processing Record 49 of Set 5 | turbat
# Processing Record 0 of Set 6 | kharan
# Processing Record 1 of Set 6 | whyalla stuart
# City not found. Skipping...
# Processing Record 2 of Set 6 | bardai
# Processing Record 3 of Set 6 | yemetsk
# Processing Record 4 of Set 6 | new norfolk
# Processing Record 5 of Set 6 | vila franca do campo
# Processing Record 6 of Set 6 | palikir - national government center
# Processing Record 7 of Set 6 | flying fish cove
# Processing Record 8 of Set 6 | dunda
# Processing Record 9 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 10 of Set 6 | remire-montjoly
# Processing Record 11 of Set 6 | portland
# Processing Record 12 of Set 6 | shofirkon shahri
# City not found. Skipping...
# Processing Record 13 of Set 6 | iringal
# Processing Record 14 of Set 6 | imbituba
# Processing Record 15 of Set 6 | kashima-shi
# Processing Record 16 of Set 6 | severo-yeniseyskiy
# Processing Record 17 of Set 6 | chebarkul'
# Processing Record 18 of Set 6 | jayapura
# Processing Record 19 of Set 6 | nefta
# Processing Record 20 of Set 6 | thinadhoo
# Processing Record 21 of Set 6 | la seu d'urgell
# Processing Record 22 of Set 6 | kisoro
# Processing Record 23 of Set 6 | laguna
# Processing Record 24 of Set 6 | dudinka
# Processing Record 25 of Set 6 | inda silase
# Processing Record 26 of Set 6 | ondjiva
# Processing Record 27 of Set 6 | colonia
# Processing Record 28 of Set 6 | tazovsky
# Processing Record 29 of Set 6 | bull savanna
# Processing Record 30 of Set 6 | suva
# Processing Record 31 of Set 6 | kudat
# Processing Record 32 of Set 6 | tura
# Processing Record 33 of Set 6 | kalemie
# Processing Record 34 of Set 6 | apple valley
# Processing Record 35 of Set 6 | ambodivoara
# Processing Record 36 of Set 6 | ndele
# Processing Record 37 of Set 6 | brisas de zicatela
# Processing Record 38 of Set 6 | antonio enes
# Processing Record 39 of Set 6 | puerto ayora
# Processing Record 40 of Set 6 | pokrovsk
# Processing Record 41 of Set 6 | cabedelo
# Processing Record 42 of Set 6 | mountain home
# Processing Record 43 of Set 6 | port lincoln
# Processing Record 44 of Set 6 | gouyave
# Processing Record 45 of Set 6 | arawa
# Processing Record 46 of Set 6 | port-gentil
# Processing Record 47 of Set 6 | trincomalee
# Processing Record 48 of Set 6 | pacific grove
# Processing Record 49 of Set 6 | santana
# Processing Record 0 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 1 of Set 7 | trail
# Processing Record 2 of Set 7 | sitka
# Processing Record 3 of Set 7 | gole
# Processing Record 4 of Set 7 | dzhalagash
# Processing Record 5 of Set 7 | fort-shevchenko
# Processing Record 6 of Set 7 | banda aceh
# Processing Record 7 of Set 7 | kalmunai
# Processing Record 8 of Set 7 | jiuquan
# Processing Record 9 of Set 7 | isangel
# Processing Record 10 of Set 7 | road town
# Processing Record 11 of Set 7 | yuncheng
# Processing Record 12 of Set 7 | salalah
# Processing Record 13 of Set 7 | alamos
# Processing Record 14 of Set 7 | baruun-urt
# Processing Record 15 of Set 7 | shendi
# Processing Record 16 of Set 7 | hirara
# Processing Record 17 of Set 7 | fort mcmurray
# Processing Record 18 of Set 7 | okahandja
# Processing Record 19 of Set 7 | nukunonu
# City not found. Skipping...
# Processing Record 20 of Set 7 | zhezqazghan
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | kingston
# Processing Record 23 of Set 7 | andi
# Processing Record 24 of Set 7 | pudasjarvi
# Processing Record 25 of Set 7 | bengkulu
# Processing Record 26 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 27 of Set 7 | noshiro
# Processing Record 28 of Set 7 | necochea
# Processing Record 29 of Set 7 | padang
# Processing Record 30 of Set 7 | orkney
# Processing Record 31 of Set 7 | fale old settlement
# Processing Record 32 of Set 7 | bansang
# Processing Record 33 of Set 7 | kill devil hills
# Processing Record 34 of Set 7 | yanchep
# Processing Record 35 of Set 7 | anadyr
# Processing Record 36 of Set 7 | gargalianoi
# Processing Record 6 of Set 9 | caleta de carquin
# Processing Record 7 of Set 9 | aykhal
# Processing Record 8 of Set 9 | chibougamau
# Processing Record 9 of Set 9 | holualoa
# Processing Record 10 of Set 9 | chicxulub puerto
# City not found. Skipping...
# Processing Record 11 of Set 9 | mabamba
# Processing Record 12 of Set 9 | lhasa
# Processing Record 13 of Set 9 | sao miguel do iguacu
# Processing Record 14 of Set 9 | punta cana
# Processing Record 15 of Set 9 | verkhnevilyuysk
# Processing Record 16 of Set 9 | andergrove
# Processing Record 17 of Set 9 | buurhakaba
# Processing Record 18 of Set 9 | owase
# Processing Record 19 of Set 9 | rongelap
# Processing Record 20 of Set 9 | kanniyakumari
# Processing Record 21 of Set 9 | lerwick
# Processing Record 22 of Set 9 | calbuco
# Processing Record 23 of Set 9 | dubbo
# Processing Record 24 of Set 9 | fortaleza
# Processing Record 25 of Set 9 | st. john's
# Processing Record 26 of Set 9 | kruisfontein
# Processing Record 27 of Set 9 | east london
# Processing Record 28 of Set 9 | gutierrez zamora
# Processing Record 29 of Set 9 | elliot lake
# Processing Record 30 of Set 9 | porto novo
# Processing Record 31 of Set 9 | ristiina
# Processing Record 32 of Set 9 | filipstad
# Processing Record 33 of Set 9 | thunder bay
# Processing Record 34 of Set 9 | laojunmiao
# Processing Record 35 of Set 9 | vernon
# Processing Record 36 of Set 9 | kyain seikgyi township
# City not found. Skipping...
# Processing Record 37 of Set 9 | pocito
# Processing Record 38 of Set 9 | kingscliff
# Processing Record 39 of Set 9 | victoria point
# Processing Record 40 of Set 9 | akrehamn
# Processing Record 41 of Set 9 | brookings
# Processing Record 42 of Set 9 | roses
# Processing Record 43 of Set 9 | hasaki
# Processing Record 44 of Set 9 | xilin hot
# Processing Record 45 of Set 9 | praia da vitoria
# Processing Record 46 of Set 9 | asau village
# City not found. Skipping...
# Processing Record 47 of Set 9 | kijang
# Processing Record 48 of Set 9 | christchurch
# Processing Record 49 of Set 9 | calatayud
# Processing Record 0 of Set 10 | ishigaki
# Processing Record 1 of Set 10 | touros
# Processing Record 2 of Set 10 | kerikeri
# Processing Record 3 of Set 10 | twentynine palms
# Processing Record 4 of Set 10 | saldanha
# Processing Record 5 of Set 10 | nha trang
# Processing Record 6 of Set 10 | papao
# Processing Record 7 of Set 10 | tadmur
# Processing Record 8 of Set 10 | flekkefjord
# Processing Record 9 of Set 10 | balqash
# Processing Record 10 of Set 10 | lamarque
# Processing Record 11 of Set 10 | haymana
# Processing Record 12 of Set 10 | liaozhong
# Processing Record 13 of Set 10 | erdenet
# Processing Record 14 of Set 10 | naha
# Processing Record 15 of Set 10 | whakatane
# Processing Record 16 of Set 10 | amahai
# Processing Record 17 of Set 10 | keflavik
# Processing Record 18 of Set 10 | dalbandin
# Processing Record 19 of Set 10 | mao
# Processing Record 20 of Set 10 | iskateley
# Processing Record 21 of Set 10 | ancud
# Processing Record 22 of Set 10 | ivolginsk
# Processing Record 23 of Set 10 | urmary
# Processing Record 24 of Set 10 | leava
# Processing Record 25 of Set 10 | oroqen zizhiqi
# Processing Record 26 of Set 10 | ourilandia do norte
# City not found. Skipping...
# Processing Record 27 of Set 10 | progreso
# Processing Record 28 of Set 10 | tutoia
# Processing Record 29 of Set 10 | hastings
# Processing Record 30 of Set 10 | villa gesell
# Processing Record 31 of Set 10 | mkushi
# Processing Record 32 of Set 10 | leua
# Processing Record 33 of Set 10 | cody
# Processing Record 34 of Set 10 | san julian
# Processing Record 35 of Set 10 | rawai
# Processing Record 36 of Set 10 | barabai
# Processing Record 37 of Set 10 | kourou
# Processing Record 38 of Set 10 | yass
# Processing Record 39 of Set 10 | changji
# Processing Record 40 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 41 of Set 10 | pemangkat
# Processing Record 42 of Set 10 | muli
# Processing Record 43 of Set 10 | victoria de durango
# Processing Record 44 of Set 10 | barah
# Processing Record 45 of Set 10 | ahau
# City not found. Skipping...
# Processing Record 46 of Set 10 | uliastay
# Processing Record 47 of Set 10 | porbandar
# Processing Record 48 of Set 10 | nikolayevsk-on-amure
# Processing Record 49 of Set 10 | manggar
# Processing Record 0 of Set 11 | kish
# Processing Record 1 of Set 11 | goshainganj
# Processing Record 2 of Set 11 | kailua-kona
# Processing Record 3 of Set 11 | olyokminsk
# Processing Record 4 of Set 11 | mount isa
# Processing Record 5 of Set 11 | bani walid
# Processing Record 6 of Set 11 | devonport
# Processing Record 7 of Set 11 | tosontsengel
# Processing Record 8 of Set 11 | angaur state
# Processing Record 9 of Set 11 | labrador city
# Processing Record 10 of Set 11 | waseca
# Processing Record 11 of Set 11 | les avirons
# Processing Record 12 of Set 11 | acarau
# Processing Record 13 of Set 11 | kurchatov
# Processing Record 14 of Set 11 | shashemene
# Processing Record 15 of Set 11 | austin
# Processing Record 16 of Set 11 | talakan
# Processing Record 17 of Set 11 | puerto san jose
# Processing Record 18 of Set 11 | watampone
# Processing Record 19 of Set 11 | tevriz
# Processing Record 20 of Set 11 | keila
# Processing Record 21 of Set 11 | voinjama
# Processing Record 22 of Set 11 | suifenhe
# Processing Record 23 of Set 11 | smithers
# Processing Record 24 of Set 11 | alofi
# Processing Record 25 of Set 11 | dakhla
# Processing Record 26 of Set 11 | cartagena del chaira
# Processing Record 27 of Set 11 | constantia
# Processing Record 28 of Set 11 | chernyshevskiy
# Processing Record 29 of Set 11 | fort st. john
# Processing Record 30 of Set 11 | cherdyn'
# Processing Record 31 of Set 11 | takamaka
# City not found. Skipping...
# Processing Record 32 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 33 of Set 11 | guapimirim
# Processing Record 34 of Set 11 | katsuren-haebaru
# Processing Record 35 of Set 11 | haiku-pauwela
# Processing Record 36 of Set 11 | makokou
# Processing Record 37 of Set 11 | sillod
# Processing Record 38 of Set 11 | pariaman
# Processing Record 39 of Set 11 | simanggang
# Processing Record 40 of Set 11 | kajatian
# Processing Record 41 of Set 11 | kaset wisai
# Processing Record 42 of Set 11 | sola
# Processing Record 43 of Set 11 | cam ranh
# Processing Record 44 of Set 11 | igrim
# Processing Record 45 of Set 11 | carutapera
# Processing Record 46 of Set 11 | tomohon
# Processing Record 47 of Set 11 | moron
# Processing Record 48 of Set 11 | niles
# Processing Record 49 of Set 11 | bereznik
# Processing Record 0 of Set 12 | hami
# Processing Record 1 of Set 12 | rocha
# Processing Record 2 of Set 12 | nalut
# Processing Record 3 of Set 12 | coquimbo
# Processing Record 4 of Set 12 | labytnangi
# Processing Record 5 of Set 12 | puerto cortez
# Processing Record 6 of Set 12 | pandan
# Processing Record 7 of Set 12 | barkhan
# Processing Record 8 of Set 12 | massakory
# Processing Record 9 of Set 12 | rikaze
# Processing Record 10 of Set 12 | tual
# Processing Record 11 of Set 12 | nema
# Processing Record 12 of Set 12 | el granada
# Processing Record 13 of Set 12 | vila velha
# Processing Record 14 of Set 12 | nagqu
# Processing Record 15 of Set 12 | teguise
# Processing Record 16 of Set 12 | kataragama
# City not found. Skipping...
# Processing Record 17 of Set 12 | nabire
# Processing Record 18 of Set 12 | tadine
# Processing Record 19 of Set 12 | fabens
# Processing Record 20 of Set 12 | port glaud
# City not found. Skipping...
# Processing Record 21 of Set 12 | port hedland
# Processing Record 22 of Set 12 | rapid valley
# Processing Record 23 of Set 12 | jakobstad
# Processing Record 24 of Set 12 | medenine
# Processing Record 25 of Set 12 | baiti
# Processing Record 26 of Set 12 | gadani
# Processing Record 27 of Set 12 | napili-honokowai
# Processing Record 28 of Set 12 | maputsoe
# Processing Record 29 of Set 12 | ermenek
# Processing Record 30 of Set 12 | greymouth
# Processing Record 31 of Set 12 | changzhou
# Processing Record 32 of Set 12 | naze
# Processing Record 33 of Set 12 | dakingari
# Processing Record 34 of Set 12 | kununurra
# Processing Record 35 of Set 12 | chom bueng
# Processing Record 36 of Set 12 | cidreira
# Processing Record 37 of Set 12 | tahe
# Processing Record 38 of Set 12 | chishmy
# Processing Record 39 of Set 12 | sault ste. marie
# Processing Record 40 of Set 12 | yakeshi
# Processing Record 41 of Set 12 | marsannay-la-cote
# Processing Record 42 of Set 12 | dobryanka
# Processing Record 43 of Set 12 | taoudenni
# Processing Record 44 of Set 12 | corner brook
# Processing Record 45 of Set 12 | marka
# Processing Record 46 of Set 12 | stephenville
# Processing Record 47 of Set 12 | challakere
# Processing Record 48 of Set 12 | tocopilla
# Processing Record 49 of Set 12 | guiuan
# Processing Record 0 of Set 13 | tshabong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          tralee  52.2704   -9.7026     10.30        94          94
# 1     bamboo flat  11.7000   92.7167     30.05        79          40
# 2     olonkinbyen  70.9221   -8.7187      1.39        98         100
# 3  puerto natales -51.7236  -72.4875      6.69        94         100
# 4       carnarvon -24.8667  113.6333     23.48        35           0
#
#    Wind Speed Country        Date
# 0        1.28      IE  1749263573
# 1        0.51      IN  1749263575
# 2        5.01      SJ  1749263127
# 3        1.26      CL  1749263404
# 4        7.00      AU  1749263578

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                tralee  52.2704   -9.7026     10.30        94          94
# 1           bamboo flat  11.7000   92.7167     30.05        79          40
# 2           olonkinbyen  70.9221   -8.7187      1.39        98         100
# 3        puerto natales -51.7236  -72.4875      6.69        94         100
# 4             carnarvon -24.8667  113.6333     23.48        35           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.28      IE  1749263573
# 1              0.51      IN  1749263575
# 2              5.01      SJ  1749263127
# 3              1.26      CL  1749263404
# 4              7.00      AU  1749263578

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor='black',  marker="o")

# Incorporate the other graph properties 
plt.title("City Max Latitude vs Temperature (2025-06-05)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor='black', marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs  Humidity (2025-06-05)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor='black', marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs  Cloudiness (2025-06-05)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor='black', marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs  Wind Speed (2025-06-05)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title):
    
    # Creates a scatter plot with linear regression line and shows the R-squared value.
    slope, intercept, r_value, p_value, std_err = stats.linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    r_squared = f"R² = {r_value**2:.3f}"

    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")

    # Show line equation and R-squared on the plot
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.annotate(line_eq, (x_values.min(), y_values.max()*0.95), fontsize=12, color="red")
    plt.annotate(r_squared, (x_values.min(), y_values.max()*0.85), fontsize=12, color="red")
    
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             tralee  52.2704   -9.7026     10.30        94          94
# 1        bamboo flat  11.7000   92.7167     30.05        79          40
# 2        olonkinbyen  70.9221   -8.7187      1.39        98         100
# 8        nova sintra  14.8667  -24.7167     23.28        84           3
# 12       yellowknife  62.4560 -114.3525     11.29        71          75
#
#          Wind Speed Country        Date
# City_ID
# 0              1.28      IE  1749263573
# 1              0.51      IN  1749263575
# 2              5.01      SJ  1749263127
# 8              5.44      CV  1749263583
# 12             8.23      CA  1749263422

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3        puerto natales -51.7236  -72.4875      6.69        94         100
# 4             carnarvon -24.8667  113.6333     23.48        35           0
# 5           nova vicosa -17.8919  -39.3719     22.07        88           9
# 6             grytviken -54.2811  -36.5092      0.38        99         100
# 7          invercargill -46.4000  168.3500      5.57        78          98
#
#          Wind Speed Country        Date
# City_ID
# 3              1.26      CL  1749263404
# 4              7.00      AU  1749263578
# 5              3.45      BR  1749263282
# 6              2.82      GS  1749263580
# 7              2.68      NZ  1749263581

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Max Temp"],
                       "Latitude",
                       "Max Temperature (C)",
                       "Northern Hemisphere: Latitude vs. Max Temperature")

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Max Temp"],
                       "Latitude",
                       "Max Temperature (C)",
                       "Southern Hemisphere: Latitude vs. Max Temperature")

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The scatter plots show a clear **negative correlation** between latitude and temperature in both hemispheres, meaning temperature **decreases as distance from the equator increases**.
#
# **Northern Hemisphere:**
# The trend shows decreasing temperatures with increasing latitude, but the data is more scattered. This suggests other geographic factors—like varied terrain and landmass—are influencing the relationship, making it less consistent.
#
# **Southern Hemisphere:**
# The trend is stronger and more linear, with temperatures rising more predictably as latitude decreases toward the equator. The tighter clustering of points indicates a clearer relationship, likely due to the ocean-dominated geography providing more uniform climate patterns.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Humidity"],
                       "Latitude",
                       "Humidity (%)",
                       "Northern Hemisphere: Latitude vs. Humidity")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Humidity"],
                       "Latitude",
                       "Humidity (%)",
                       "Southern Hemisphere: Latitude vs. Humidity")

# %% [markdown]
# **Discussion about the linear relationship:**
#
# * Both scatter plots display **no clear relationship** between **latitude** and **humidity**.
# * The **R² values** are very low in both hemispheres, confirming that **latitude does not explain humidity levels**.
# * **Northern Hemisphere:** The data is widely scattered with no trend—latitude has little effect on humidity.
# * **Southern Hemisphere:** The regression line shows a slight upward slope, but the R² value (\~0.007) indicates it's **statistically meaningless**.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Cloudiness"],
                       "Latitude",
                       "Cloudiness (%)",
                       "Northern Hemisphere: Latitude vs. Cloudiness")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Cloudiness"],
                       "Latitude",
                       "Cloudiness (%)",
                       "Southern Hemisphere: Latitude vs. Cloudiness")

# %% [markdown]
# **Discussion about the linear relationship:**
#
# * Both hemispheres show **no strong relationship** between latitude and cloudiness.
# * **R² values are very low**, confirming that **latitude is not a reliable predictor** of cloud cover.
# * **Scatter plots appear random**, indicating **local weather conditions** are more influential.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df["Lat"],
                       northern_hemi_df["Wind Speed"],
                       "Latitude",
                       "Wind Speed (m/s)",
                       "Northern Hemisphere: Latitude vs. Wind Speed")

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df["Lat"],
                       southern_hemi_df["Wind Speed"],
                       "Latitude",
                       "Wind Speed (m/s)",
                       "Southern Hemisphere: Latitude vs. Wind Speed")

# %% [markdown]
# **Discussion about the linear relationship:**
#
# * Both hemispheres exhibit **very low R² values**, showing **no significant correlation** between latitude and wind speed.
# * The **Northern Hemisphere** trend is **nearly flat**.
# * The **Southern Hemisphere** shows a **slightly downward slope**, but **both trends are weak and not meaningful**.
